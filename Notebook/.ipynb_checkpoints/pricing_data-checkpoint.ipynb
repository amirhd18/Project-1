# %%
import pandas as pd
from pathlib import Path
import numpy as np
import datetime as dt
from pathlib import Path
import seaborn as sns

# %matplotlib inline

# %%
pricing = Path("c:/Users/amirh/Project-1/Data/Raw/prices_in_new_york.csv")

# %%
pricing = pd.read_csv(pricing)

# %%
pricing.head()
# Out:
#    Rank                              City  Meal, Inexpensive Restaurant  \
# 0   NaN                               NaN                           NaN
# 1   NaN                               NaN                           NaN
# 2   1.0         Boston, MA, United States                          20.0
# 3   2.0  San Francisco, CA, United States                          20.0
# 4   3.0    Los Angeles, CA, United States                          20.0
#
#                    Meal for 2 People,         McMeal at McDonalds  \
# 0  Mid-range Restaurant, Three-course  (or Equivalent Combo Meal)
# 1                                 NaN                         NaN
# 2                                  80                           9
# 3                                  80                          10
# 4                                77.5                           9
#
#          Domestic Beer        Imported Beer           Coke/Pepsi  \
# 0  (0.5 liter draught)  (0.33 liter bottle)  (0.33 liter bottle)
# ...

# %%
mask = pricing.City.str.count(',') > 1
pricing[mask].head()
# Out:
#    Rank                              City  Meal, Inexpensive Restaurant  \
# 2   1.0         Boston, MA, United States                          20.0
# 3   2.0  San Francisco, CA, United States                          20.0
# 4   3.0    Los Angeles, CA, United States                          20.0
# 5   4.0       New York, NY, United States                          20.0
# 6   5.0       Portland, OR, United States                          18.0
#
#   Meal for 2 People, McMeal at McDonalds Domestic Beer Imported Beer  \
# 2                 80                   9             7             8
# 3                 80                  10             8           8.5
# 4               77.5                   9             7             8
# 5                100                   9          7.35             9
# 6               62.5                 7.5             6             6
#
#   Coke/Pepsi Water  Milk  ... Lettuce Cappuccino  Rice Tomato Banana Onion  \
# ...

# %%
us_pricing = pricing[pricing.City.str.count(',') > 1]
us_pricing.head()
# Out:
#    Rank                              City  Meal, Inexpensive Restaurant  \
# 2   1.0         Boston, MA, United States                          20.0
# 3   2.0  San Francisco, CA, United States                          20.0
# 4   3.0    Los Angeles, CA, United States                          20.0
# 5   4.0       New York, NY, United States                          20.0
# 6   5.0       Portland, OR, United States                          18.0
#
#   Meal for 2 People, McMeal at McDonalds Domestic Beer Imported Beer  \
# 2                 80                   9             7             8
# 3                 80                  10             8           8.5
# 4               77.5                   9             7             8
# 5                100                   9          7.35             9
# 6               62.5                 7.5             6             6
#
#   Coke/Pepsi Water  Milk  ... Lettuce Cappuccino  Rice Tomato Banana Onion  \
# ...

# %%
us_pricing
# Out:
#     Rank                              City  Meal, Inexpensive Restaurant  \
# 2    1.0         Boston, MA, United States                         20.00
# 3    2.0  San Francisco, CA, United States                         20.00
# 4    3.0    Los Angeles, CA, United States                         20.00
# 5    4.0       New York, NY, United States                         20.00
# 6    5.0       Portland, OR, United States                         18.00
# 7    6.0        Seattle, WA, United States                         18.00
# 12  11.0        Chicago, IL, United States                         16.00
# 13  12.0         Denver, CO, United States                         15.76
# 14  13.0        Orlando, FL, United States                         15.50
# 16  15.0         Austin, TX, United States                         15.00
# 17  16.0         Dallas, TX, United States                         15.00
# 18  17.0    San Antonio, TX, United States                         15.00
# ...

# %%
us_pricing[['City Name', 'State', 'Country']] = us_pricing.City.str.split(',', expand=True)
# Out:
# C:\Users\amirh\anaconda3\envs\FinTech\lib\site-packages\pandas\core\frame.py:3191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
us_pricing
# Out:
#     Rank                              City  Meal, Inexpensive Restaurant  \
# 2    1.0         Boston, MA, United States                         20.00
# 3    2.0  San Francisco, CA, United States                         20.00
# 4    3.0    Los Angeles, CA, United States                         20.00
# 5    4.0       New York, NY, United States                         20.00
# 6    5.0       Portland, OR, United States                         18.00
# 7    6.0        Seattle, WA, United States                         18.00
# 12  11.0        Chicago, IL, United States                         16.00
# 13  12.0         Denver, CO, United States                         15.76
# 14  13.0        Orlando, FL, United States                         15.50
# 16  15.0         Austin, TX, United States                         15.00
# 17  16.0         Dallas, TX, United States                         15.00
# 18  17.0    San Antonio, TX, United States                         15.00
# ...

# %%
monthly_income=us_pricing[['City Name', 'State','Average Monthly Net Salary']]

# %%
monthly_income.dtypes
# Out:
# City Name                     object
# State                         object
# Average Monthly Net Salary    object
# dtype: object

# %%
monthly_income['Average Monthly Net Salary'] = monthly_income['Average Monthly Net Salary'].str.replace(',', '').astype(float).astype(int)
# Out:
# C:\Users\amirh\anaconda3\envs\FinTech\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
monthly_income_sorted= monthly_income.sort_values(by='Average Monthly Net Salary')

# %%
monthly_income_sorted
# Out:
#         City Name State  Average Monthly Net Salary  Average Annual Net Salary
# 21        Spokane    WA                        2838                      34056
# 18    San Antonio    TX                        3260                      39120
# 25          Miami    FL                        3447                      41364
# 14        Orlando    FL                        3633                      43596
# 24      Las Vegas    NV                        3699                      44388
# 6        Portland    OR                        3989                      47868
# 13         Denver    CO                        4619                      55428
# 22        Houston    TX                        4682                      56184
# 16         Austin    TX                        4876                      58512
# 12        Chicago    IL                        4897                      58764
# 4     Los Angeles    CA                        5004                      60048
# ...

# %%
monthly_income_sorted['Average Annual Net Salary']= monthly_income_sorted['Average Monthly Net Salary']*12

# %%
monthly_income_sorted.plot(x='City Name', y='Average Monthly Net Salary',kind='bar', rot=45, figsize=(20, 10))

# %%
monthly_income_sorted.plot(x='City Name', y='Average Annual Net Salary',kind='bar', rot=45, figsize=(20, 10))
